# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
students_perfomance = pd.read_csv('C:/Users/TatarnikovVS/Downloads/StudentsPerformance.csv')
students_perfomance.columns = students_perfomance.columns.str.replace(' ', '_')

# %%
students_perfomance.head()
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
students_perfomance.math_score.hist()
# Out:
# <Axes: >

# %%
students_perfomance.plot.scatter(x='math_score', y='reading_score')
# Out:
# <Axes: xlabel='math_score', ylabel='reading_score'>

# %%
ax = sns.lmplot(x='math_score', y='reading_score', data=students_perfomance,\
           hue='gender', fit_reg=False)
ax.set_xlabels('Maths core')
ax.set_ylabels('Reading score')

# %%
df = pd.read_csv('C:\\Users\\TatarnikovVS\\Downloads\\income.csv')

# %%
plt.plot(df.index, df.income)

# %%
df = pd.read_csv('C:\\Users\\TatarnikovVS\\Downloads\\dataset_209770_6.txt', sep=' ')

# %%
df
# Out:
#              x            y
# 0   824.314414  1297.644355
# 1   287.997197   901.624990
# 2   500.332649  1491.552116
# 3   816.681120  1302.559684
# 4   906.723720   404.355266
# ..         ...          ...
# 65  789.289008  1293.370249
# 66  300.605909   893.304408
# 67  488.585858  1497.066971
# 68  301.965340   907.811236
# 69  799.044174  1309.162822
#
# [70 rows x 2 columns]

# %%
sns.lineplot(x=df.x, y=df.y)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
ax = sns.lmplot(x='x', y='y', data=df, fit_reg=False)

# %%
g = pd.read_csv('C:\\Users\\TatarnikovVS\\Downloads\\genome_matrix.csv', index_col=0)
# g.xaxis.set_ticks_position('top')
# g.xaxis.set_tick_params(rotation=90)

# %%
g
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
res = sns.heatmap(g, cmap='viridis')
res.xaxis.set_ticks_position('top')
res.xaxis.set_tick_params(rotation=90)

# %%
dota_heros = pd.read_csv('C:\\Users\\TatarnikovVS\\Downloads\\dota_hero_stats.csv', index_col=0)

# %%
dota_heros
# Out:
#     attack_type   id  legs  localized_name                          name  \
# 0         Melee    1     2       Anti-Mage        npc_dota_hero_antimage
# 1         Melee    2     2             Axe             npc_dota_hero_axe
# 2        Ranged    3     4            Bane            npc_dota_hero_bane
# 3         Melee    4     2     Bloodseeker     npc_dota_hero_bloodseeker
# 4        Ranged    5     2  Crystal Maiden  npc_dota_hero_crystal_maiden
# ..          ...  ...   ...             ...                           ...
# 112       Melee  114     2     Monkey King     npc_dota_hero_monkey_king
# 113      Ranged  119     2     Dark Willow     npc_dota_hero_dark_willow
# 114       Melee  120     2       Pangolier       npc_dota_hero_pangolier
# 115      Ranged  121     2      Grimstroke      npc_dota_hero_grimstroke
# 116       Melee  129     2            Mars            npc_dota_hero_mars
#
#     primary_attr                                              roles
# ...

# %%
# sns.barplot(data=dota_heros, y='roles')

# %%
dota_heros.sort_values('roles')
# Out:
#     attack_type   id  legs    localized_name                            name  \
# 79        Melee   81     2      Chaos Knight      npc_dota_hero_chaos_knight
# 92       Ranged   94     0            Medusa            npc_dota_hero_medusa
# 102       Melee  104     2  Legion Commander  npc_dota_hero_legion_commander
# 67        Melee   69     2              Doom      npc_dota_hero_doom_bringer
# 17        Melee   18     2              Sven              npc_dota_hero_sven
# ..          ...  ...   ...               ...                             ...
# 108      Ranged  110     2           Phoenix           npc_dota_hero_phoenix
# 38       Ranged   40     0        Venomancer        npc_dota_hero_venomancer
# 62       Ranged   64     2            Jakiro            npc_dota_hero_jakiro
# 29       Ranged   31     2              Lich              npc_dota_hero_lich
# 25       Ranged   27     2     Shadow Shaman     npc_dota_hero_shadow_shaman
#
# ...

# %%
dota_heros['role_count'] = dota_heros['roles'].count()

# %%
dota_heros.iloc[[0]]['roles']
# Out:
# 0    ['Carry', 'Escape', 'Nuker']
# Name: roles, dtype: object

# %%
dota_heros['cnt'] = dota_heros.roles.str.count(',')+1

# %%
dota_heros.sort_values('cnt', ascending=False)
# Out:
#     attack_type   id  legs    localized_name                            name  \
# 87        Melee   89     0        Naga Siren        npc_dota_hero_naga_siren
# 18        Melee   19     2              Tiny              npc_dota_hero_tiny
# 47        Melee   49     2     Dragon Knight     npc_dota_hero_dragon_knight
# 15        Melee   16     6         Sand King         npc_dota_hero_sand_king
# 80        Melee   82     2             Meepo             npc_dota_hero_meepo
# ..          ...  ...   ...               ...                             ...
# 103      Ranged  105     6           Techies           npc_dota_hero_techies
# 10       Ranged   11     0      Shadow Fiend         npc_dota_hero_nevermore
# 42        Melee   44     2  Phantom Assassin  npc_dota_hero_phantom_assassin
# 33       Ranged   35     2            Sniper            npc_dota_hero_sniper
# 21       Ranged   22     2              Zeus              npc_dota_hero_zuus
#
# ...

# %%
dota_heros.loc[dota_heros['cnt'] == 6]
# Out:
#     attack_type   id  legs localized_name                         name  \
# 114       Melee  120     2      Pangolier      npc_dota_hero_pangolier
# 22        Melee   23     2         Kunkka         npc_dota_hero_kunkka
# 71        Melee   73     2      Alchemist      npc_dota_hero_alchemist
# 80        Melee   82     2          Meepo          npc_dota_hero_meepo
# 15        Melee   16     6      Sand King      npc_dota_hero_sand_king
# 47        Melee   49     2  Dragon Knight  npc_dota_hero_dragon_knight
# 18        Melee   19     2           Tiny           npc_dota_hero_tiny
# 87        Melee   89     0     Naga Siren     npc_dota_hero_naga_siren
#
#     primary_attr                                              roles  \
# 114          agi  ['Carry', 'Nuker', 'Disabler', 'Durable', 'Esc...
# 22           str  ['Carry', 'Support', 'Disabler', 'Initiator', ...
# 71           str  ['Carry', 'Support', 'Durable', 'Disabler', 'I...
# ...

# %%
sns.barplot(x="localized_name", y="cnt", data=dota_heros);

# %%
sns.distplot([x.count(',')+1 for x in dota_heros.roles], bins=15)
# Out:
# C:\Users\TatarnikovVS\AppData\Local\Temp\ipykernel_10980\839450670.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([x.count(',')+1 for x in dota_heros.roles], bins=15)
# <Axes: ylabel='Density'>

# %%
iris = pd.read_csv('C:\\Users\\TatarnikovVS\\Downloads\\iris.csv', index_col=0)

# %%
iris
# Out:
#      sepal length  sepal width  petal length  petal width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
for colum in iris:
    sns.histplot(iris[colum])

# %%
for colum in iris:
    sns.kdeplot(iris[colum])

# %%
sns.kdeplot(data=iris)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.violinplot(iris['petal length'])
# Out:
# <Axes: >

# %%
sns.pairplot(iris)
