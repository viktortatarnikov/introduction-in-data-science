# %%
import pandas as pd 
import numpy as np

# %%
titanik = pd.read_csv('C:/Users/TatarnikovVS/Downloads/titanic(1).csv')

# %%
titanik.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
len(titanik.columns)
# Out:
# 12

# %%
len(titanik.index)
# Out:
# 891

# %%
titanik.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanik.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanik.dtypes.value_counts()
# Out:
# int64      5
# object     5
# float64    2
# dtype: int64

# %%
titanik.dtypes.value_counts()['int64']
# Out:
# 5

# %%
df = pd.read_csv('C:/Users/TatarnikovVS/Downloads/column_hell.csv')
selected_columns = df.filter(like='-')

# %%
selected_columns
# Out:
#      umeca-4  kudbpyw-3       g-3       v-9     fla-6  hwtbyrkp-5
# 0   0.016124   0.430787  0.202407  0.725508  0.305076    0.979296
# 1   0.507115   0.671662  0.864249  0.867818  0.358859    0.160520
# 2   0.003274   0.286411  0.928865  0.719159  0.340235    0.734612
# 3   0.784139   0.863717  0.175446  0.554744  0.049325    0.621132
# 4   0.011265   0.206172  0.044151  0.163643  0.048806    0.437836
# ..       ...        ...       ...       ...       ...         ...
# 95  0.220817   0.434444  0.601738  0.146333  0.918888    0.216499
# 96  0.474131   0.176011  0.359793  0.104707  0.257690    0.066934
# 97  0.091637   0.871606  0.121075  0.907699  0.313184    0.788592
# 98  0.360106   0.172385  0.015285  0.019571  0.060751    0.403166
# 99  0.669284   0.701505  0.481430  0.024944  0.644989    0.702003
#
# [100 rows x 6 columns]

# %%
students_perfomance = pd.read_csv('C:/Users/TatarnikovVS/Downloads/StudentsPerformance.csv')

# %%
students_perfomance.columns = students_perfomance.columns.str.replace(' ', '_')
students_perfomance
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
mean_scores = students_perfomance.groupby(['gender', 'race/ethnicity']).\
aggregate({'math_score': 'mean', 'reading_score': 'mean'})\
.rename(columns= {'math_score': 'mean_math_score', 'reading_score': 'mean_reading_score'})

# %%
mean_scores
# Out:
#                        mean_math_score  mean_reading_score
# gender race/ethnicity
# female group A               58.527778           69.000000
#        group B               61.403846           71.076923
#        group C               62.033333           71.944444
#        group D               65.248062           74.046512
#        group E               70.811594           75.840580
# male   group A               63.735849           61.735849
#        group B               65.930233           62.848837
#        group C               67.611511           65.424460
#        group D               69.413534           66.135338
#        group E               76.746479           70.295775

# %%
mean_scores.loc[[('female', 'group A'), ('female', 'group B')]]
# Out:
#                        mean_math_score  mean_reading_score
# gender race/ethnicity
# female group A               58.527778           69.000000
#        group B               61.403846           71.076923

# %%
students_perfomance.groupby(['gender', 'race/ethnicity']).math_score.nunique()
# Out:
# gender  race/ethnicity
# female  group A           29
#         group B           51
#         group C           59
#         group D           53
#         group E           44
# male    group A           38
#         group B           43
#         group C           56
#         group D           49
#         group E           38
# Name: math_score, dtype: int64

# %%
students_perfomance.sort_values(['gender', 'race/ethnicity'], ascending=False) \
.groupby('gender').head(5)
# Out:
#     gender race/ethnicity parental_level_of_education         lunch  \
# 34    male        group E                some college      standard
# 35    male        group E          associate's degree      standard
# 50    male        group E                some college      standard
# 51    male        group E          associate's degree  free/reduced
# 60    male        group E           bachelor's degree  free/reduced
# 32  female        group E             master's degree  free/reduced
# 44  female        group E          associate's degree  free/reduced
# 56  female        group E          associate's degree      standard
# 79  female        group E             master's degree      standard
# 97  female        group E                some college      standard
#
#    test_preparation_course  math_score  reading_score  writing_score
# 34                    none          97             87             82
# 35               completed          81             81             79
# ...

# %%
students_perfomance['total_score'] = students_perfomance.math_score + students_perfomance.reading_score + students_perfomance.writing_score

# %%
students_perfomance = students_perfomance.assign(total_score_log = np.log(students_perfomance['total_score']))

# %%
students_perfomance
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# ...

# %%
students_perfomance.drop(['total_score'], axis=1)
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# ...

# %%
dota_data = pd.read_csv('C:\\Users\\TatarnikovVS\\Downloads\\dota_hero_stats.csv')

# %%
dota_data
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
dota_data.groupby('legs').head()
# Out:
#      Unnamed: 0 attack_type   id  legs     localized_name  \
# 0             0       Melee    1     2          Anti-Mage
# 1             1       Melee    2     2                Axe
# 2             2      Ranged    3     4               Bane
# 3             3       Melee    4     2        Bloodseeker
# 4             4      Ranged    5     2     Crystal Maiden
# 5             5      Ranged    6     2        Drow Ranger
# 9             9      Ranged   10     0          Morphling
# 10           10      Ranged   11     0       Shadow Fiend
# 14           14      Ranged   15     0              Razor
# 15           15       Melee   16     6          Sand King
# 26           26       Melee   28     0            Slardar
# 31           31      Ranged   33     0             Enigma
# 50           50      Ranged   52     4            Leshrac
# 56           56      Ranged   58     4        Enchantress
# 59           59       Melee   61     8        Broodmother
# ...

# %%
dota_data.value_counts('legs')
# Out:
# legs
# 2    95
# 0    11
# 4     7
# 6     3
# 8     1
# dtype: int64

# %%
dota_data.groupby('legs').size()
# Out:
# legs
# 0    11
# 2    95
# 4     7
# 6     3
# 8     1
# dtype: int64

# %%
dota_data.aggregate({'legs': 'value_counts'})
# Out:
#    legs
# 2    95
# 0    11
# 4     7
# 6     3
# 8     1

# %%
dota_data.groupby('attack_type').count()
# Out:
#              Unnamed: 0  id  legs  localized_name  name  primary_attr  roles
# attack_type
# Melee                56  56    56              56    56            56     56
# Ranged               61  61    61              61    61            61     61

# %%
df =  pd.read_csv('C:\\Users\\TatarnikovVS\\Downloads\\accountancy.csv')

# %%
df
# Out:
#     Unnamed: 0 Executor Type  Salary
# 0            0     Pupa    D      63
# 1            1     Pupa    A     158
# 2            2     Pupa    D     194
# 3            3     Pupa    E     109
# 4            4    Loopa    E     184
# 5            5    Loopa    F     232
# 6            6    Loopa    B     249
# 7            7     Pupa    F     195
# 8            8     Pupa    A     115
# 9            9     Pupa    E      65
# 10          10    Loopa    C     145
# 11          11    Loopa    D     149
# 12          12    Loopa    B      50
# 13          13     Pupa    A     217
# 14          14    Loopa    D     110
# 15          15     Pupa    F      62
# 16          16     Pupa    A      55
# 17          17    Loopa    B     190
# 18          18    Loopa    E      83
# 19          19     Pupa    A     234
# 20          20    Loopa    E     156
# 21          21    Loopa    E     219
# 22          22     Pupa    C      55
# 23          23     Pupa    D     144
# ...

# %%
df.drop('Unnamed: 0', axis=1)#.groupby(['Executor', 'Type']).aggregate({'Salary': 'mean'})
# Out:
#    Executor Type  Salary
# 0      Pupa    D      63
# 1      Pupa    A     158
# 2      Pupa    D     194
# 3      Pupa    E     109
# 4     Loopa    E     184
# 5     Loopa    F     232
# 6     Loopa    B     249
# 7      Pupa    F     195
# 8      Pupa    A     115
# 9      Pupa    E      65
# 10    Loopa    C     145
# 11    Loopa    D     149
# 12    Loopa    B      50
# 13     Pupa    A     217
# 14    Loopa    D     110
# 15     Pupa    F      62
# 16     Pupa    A      55
# 17    Loopa    B     190
# 18    Loopa    E      83
# 19     Pupa    A     234
# 20    Loopa    E     156
# 21    Loopa    E     219
# 22     Pupa    C      55
# 23     Pupa    D     144
# 24     Pupa    C      94
# 25    Loopa    C     175
# 26    Loopa    D      78
# 27    Loopa    C      81
# 28     Pupa    E     197
# 29     Pupa    E     193
# 30     Pupa    E      92
# 31     Pupa    D     185
# 32    Loopa    B     128
# 33     Pupa    F     146
# 34    Loopa    B      69
# 35    Loopa    F     244
# ...

# %%
res1 = df.groupby(['Executor', 'Type'])

# %%
res1

# %%
res = df.groupby(['Executor', 'Type']).mean().Salary
answer = [res.Loopa > res.Pupa]

# %%
res
# Out:
# Executor  Type
# Loopa     A        58.000000
#           B       145.166667
#           C       154.333333
#           D       137.714286
#           E       164.000000
#           F       238.000000
# Pupa      A       160.833333
#           B        77.000000
#           C        74.500000
#           D       146.500000
#           E       131.200000
#           F       136.250000
# Name: Salary, dtype: float64

# %%
answer
# Out:
# [Type
#  A    False
#  B     True
#  C     True
#  D    False
#  E     True
#  F     True
#  Name: Salary, dtype: bool]

# %%
df.drop('Unnamed: 0', axis=1) \
    .groupby(['Type', 'Executor'], as_index=False) \
    .mean() \
    .sort_values(['Type', 'Salary'], ascending=[True, False]) \
    .groupby('Type') \
    .head(1)
# Out:
#    Type Executor      Salary
# 1     A     Pupa  160.833333
# 2     B    Loopa  145.166667
# 4     C    Loopa  154.333333
# 7     D     Pupa  146.500000
# 8     E    Loopa  164.000000
# 10    F    Loopa  238.000000

# %%
df.drop('Unnamed: 0', axis=1) \
    .groupby(['Type', 'Executor'], as_index=False) \
    .mean().sort_values(['Type', 'Salary'], ascending=[True, False]) \
    .groupby('Type') \
    .head(1)
# Out:
#    Type Executor      Salary
# 1     A     Pupa  160.833333
# 2     B    Loopa  145.166667
# 4     C    Loopa  154.333333
# 7     D     Pupa  146.500000
# 8     E    Loopa  164.000000
# 10    F    Loopa  238.000000

# %%
df.groupby(['Type','Executor']).mean().unstack()
# Out:
#          Unnamed: 0             Salary
# Executor      Loopa   Pupa       Loopa        Pupa
# Type
# A         46.000000  16.00   58.000000  160.833333
# B         24.000000  41.00  145.166667   77.000000
# C         31.666667  23.00  154.333333   74.500000
# D         31.857143  14.00  137.714286  146.500000
# E         23.500000  19.80  164.000000  131.200000
# F         20.000000  25.75  238.000000  136.250000

# %%
dota_data.groupby(['attack_type', 'primary_attr'], as_index=False)\
    .aggregate({'id': 'count'}).sort_values('id', ascending=False)
# Out:
#   attack_type primary_attr  id
# 4      Ranged          int  40
# 2       Melee          str  35
# 0       Melee          agi  19
# 3      Ranged          agi  18
# 5      Ranged          str   3
# 1       Melee          int   2

# %%
dota_data.groupby(['attack_type','primary_attr']).count()
# Out:
#                           Unnamed: 0  id  legs  localized_name  name  roles
# attack_type primary_attr
# Melee       agi                   19  19    19              19    19     19
#             int                    2   2     2               2     2      2
#             str                   35  35    35              35    35     35
# Ranged      agi                   18  18    18              18    18     18
#             int                   40  40    40              40    40     40
#             str                    3   3     3               3     3      3

# %%
dota_data.filter(items=['attack_type','primary_attr']).mode()
# Out:
#   attack_type primary_attr
# 0      Ranged          int
